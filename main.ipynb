# %%
url = "https://www.reddit.com/r/forhire/new/"

# %% [markdown]
# # Scraping Flairs

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# Specify the subreddit you want to scrape
subreddit_url = url

# Set up the Chrome WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(subreddit_url)

# Accept Reddit's cookies if prompted (optional)
try:
    cookies_button = driver.find_element(By.XPATH, "//button[contains(text(), 'Accept All')]")
    cookies_button.click()
except:
    pass

# Scroll a few times to load more posts
scroll_pause_time = 2
scroll_count = 10
for _ in range(scroll_count):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)

# Find post flairs
flairs = driver.find_elements(By.CLASS_NAME, "flair-content")

# Extract and print the flair text
for flair in flairs:
    print(flair.text)

# Close the browser
driver.quit()
# Out:
# Hiring
# For Hire
# Hiring - Open
# Hiring
# Hiring
# For Hire
# For Hire
# For Hire
# For Hire
# For Hire
# Hiring
# Hiring - Open
# For Hire
# For Hire
# For Hire
# For Hire
# For Hire
# For Hire
# For Hire
# Hiring
# For Hire
# For Hire
# Hiring
# For Hire
# Hiring
# For Hire
# For Hire
# Hiring
# Hiring
# For Hire
# For Hire
# Hiring - Open
# For Hire
# For Hire
# Hiring
# Hiring
# For Hire
# For Hire
# For Hire
# For Hire
# For Hire
# For Hire
# Hiring
# Hiring
# For Hire
# Hiring
# Hiring
# For Hire
# For Hire
# For Hire

# %% [markdown]
# # Working Code but only fetching from the main page ( i.e partial description )

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# Specify the subreddit you want to scrape
subreddit_url = url

# Set up the Chrome WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(subreddit_url)

# Accept Reddit's cookies if prompted (optional)
try:
    cookies_button = driver.find_element(By.XPATH, "//button[contains(text(), 'Accept All')]")
    cookies_button.click()
except:
    pass

# Scroll a few times to load more posts
scroll_pause_time = 2
scroll_count = 5
for _ in range(scroll_count):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)

# Extract titles, flairs, and descriptions
titles = driver.find_elements(By.CLASS_NAME, "block.font-semibold.text-neutral-content-strong.m-0.visited\\:text-neutral-content-weak.text-16.xs\\:text-18.mb-2xs.xs\\:mb-xs.overflow-hidden")
flairs = driver.find_elements(By.CLASS_NAME, "flair-content")
descriptions = driver.find_elements(By.CLASS_NAME, "hover\\:no-underline.no-underline.pointer-events-none.text-neutral-content.visited\\:text-neutral-content-weak")

# Loop through the extracted data and print them
for i in range(len(titles)):
    title = titles[i].text if i < len(titles) else "N/A"
    flair = flairs[i].text if i < len(flairs) else "N/A"
    description = descriptions[i].text if i < len(descriptions) else "N/A"
    
    print(f"Post {i+1}:")
    print(f"Title: {title}")
    print(f"Flair: {flair}")
    print(f"Description: {description}")
    print("-" * 40)

# Close the browser
driver.quit()
# Out:
# Post 1:
# Title: [For Hire] Authentic Anime Portraits based on a photo reference
# Flair: For Hire
# Description: 80$ per head portrait
# 120$ per half-body portrait
# 160$ per full-body portrait https://imgur.com/GWz9u6I
# ----------------------------------------
# Post 2:
# Title: [For Hire] Web Designer/ Landing Page Designer/ UI UX
# Flair: For Hire
# Description: Hey everyone, I'm a freelance online web designer that’s specialized in creating landing pages for diferent businesses, and writing the copy to fill it with. This way I ensure not only that your page will look good, but also that it will convert more. Need an introductory Landing Page for your SAAS, or maybe your agency? No matter what business you have, I've got you covered! Portfolio: https://www.behance.net/gallery/208797621/My-Work If you’re interested, feel free to let me know. Just comment on this post, or send me a DM Email: jcdsdepaula@hotmail.com
# ----------------------------------------
# Post 3:
# ...

# %% [markdown]
# # Beautiful Soup

# %%
import csv
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Specify the subreddit URL
subreddit_url = url

# Set up the Chrome WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("--disable-blink-features=AutomationControlled")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(subreddit_url)

# Accept Reddit's cookies if prompted (optional)
try:
    cookies_button = driver.find_element(By.XPATH, "//button[contains(text(), 'Accept All')]")
    cookies_button.click()
except:
    pass

# Scroll the page a few times to load more posts
scroll_pause_time = 2
scroll_count = 2

for _ in range(scroll_count):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)

# After scrolling, get the page source for Beautiful Soup
page_source = driver.page_source

# Close the Selenium driver
driver.quit()

# Parse the page source with Beautiful Soup
soup = BeautifulSoup(page_source, "html.parser")

# List to store the scraped data
scraped_data = []

# Find all post containers
posts = soup.find_all(id=lambda x: x and x.startswith("post-title-t3_"))

# Loop through each post container and extract data
for post in posts:
    # Extract the unique post ID from the title's id attribute
    post_id = post.get("id").replace("post-title-", "")
    
    # Get the title
    title = post.get_text(strip=True)
    
    # Find the flair using the extracted post ID
    # flair = soup.find(attrs={"post-id": post_id})
    # flair = soup.find("div", class_="flair-content [&_.flair-image]:align-bottom max-w-full overflow-hidden whitespace-nowrap text-ellipsis")
    # flairs = driver.find_elements(By.CLASS_NAME, "flair-content")
    # flair_text = flairs[0].text if flairs else "N/A"  # Adjust to get specific flair as needed
    # flair_text = flair.get_text(strip=True) if flair else "N/A"
    
    # Find the description content
    description_div = soup.find(id=f"{post_id}-post-rtjson-content")
    if description_div:
        paragraphs = description_div.find_all("p")
        description = "\n".join([p.get_text(strip=True) for p in paragraphs])
    else:
        description = "N/A"
    
    # Store the data in a dictionary
    post_data = {
        "Post ID": post_id,
        "Title": title,
        "Flair": flair_text,
        "Description": description
    }
    
    scraped_data.append(post_data)


for i in scraped_data:
    # Get the title
    title = i['Title']
    
    # Use regex to identify and tag the flair
    if re.search(r'\[For Hire\]', title, re.IGNORECASE):
        i['Flair'] = "For Hire"
    elif re.search(r'\[Hiring\]', title, re.IGNORECASE):
        i['Flair'] = "Hiring"
    else:
        i['Flair'] = "Other"

# %%
for i in scraped_data:
    print(i['Description'])
    print('\n')
    print("="*40)
# Out:
# With 15 years of experience I can help you solve anything related to WordPress just like I have done with more than 1,000 verifiable customers.
# Here are some the things I can do for you:
# Full site development
# Plugin and theme development
# Theme customization
# Bug Fixing
# Performance optimization
# Maintenance
# I also have experience working in related areas.
# SEO
# SEM
# Content writing (I run a small niche site)
# UI/UX
# Browser game development
# Some of the benefits of working with me:
# Fast turnaround -Get your project done quickly while maintaining high quality.
# Excellent communication -I have worked with more than 1,000 customers on several platforms. I understand that good communication is essential to get any project done effectively.
# Experience -I've been working with WordPress for more than 15 years.
# About me:
# I have developed have developed commercial plugins and themes that have sold more than 3,000 copies.
# ...
